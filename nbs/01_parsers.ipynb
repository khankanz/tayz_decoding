# %% [markdown]
# # parsers
#
# > We need logic to turn LLM output(s), whether thinking models, some odd output format *ahem Qwen* into consistent clear text we can work with. Hence *parsers*.

# %%
#| default_exp parsers

# %%
#| hide
from nbdev.showdoc import *

# %%
#| hide 
#| export
import logging
from typing import Callable, Any

# %% [markdown]
# This Parser class approach has been largely lifted from the awesome verifiers lib.

# %%
#| export
class Parser:
    """
    Parser class.

    Default behavior:
    - `parse` returns text as-is
    - `parse_answer` returns the last message's content (or text if string)
    """
    def __init__(self, xfn: Callable[[str], str] = lambda x: x):
        self.logger = logging.getLogger(f"tayz-decoding.parsers.{self.__class__.__name__}")
        self.xfn = xfn
    def parse(self, txt: str) -> Any: return self.xfn(txt)

# %%
#| hide
import nbdev; nbdev.nbdev_export()
